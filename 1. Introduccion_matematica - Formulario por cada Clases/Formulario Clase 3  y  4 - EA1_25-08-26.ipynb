# %% [markdown]
# # Formulario Python para MAT2121

# %% [markdown]
# ## Cargar librerías siempre

# %%
# %pip install pandas numpy matplotlib scipy # Instala las liberías necesarias
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %% [markdown]
# ## Importar bibliotecas o librerías

# %%
import numpy as np                  # Cálculos numéricos, vectores y matrices
import pandas as pd                 # Manipulación y análisis de bases de datos
import matplotlib.pyplot as plt     # Creación de gráficos
from scipy.optimize import fsolve   # Resolución numérica de ecuaciones

# %% [markdown]
# ## Manipulación de listas

# %%
lista = [1, 2, 3, 4]
primer_elemento = lista[0] #Muestra el 1
ultimo_eleneto = lista[-1] #Muestra el 4

# %% [markdown]
# ## Definición de una función

# %%
def suma(a, b):
    return a + b
# para evaluar e interpretar el resultado
print(f'A los xx variable independiente contexto se transmiten {f(xx):.0f} Variable dependiente contexto.')   #resultado dentro de un texto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 def suma(a, b):
#       2     return a + b
#       3 # para evaluar e interpretar el resultado
# ----> 4 print(f'A los xx variable independiente contexto se transmiten {f(xx):.0f} Variable dependiente contexto.')   #resultado dentro de un texto
#
# NameError: name 'f' is not defined

# %% [markdown]
# ## Tabla de datos

# %%
def tabla_datos():
  for i in range(inicio, fin más el aumento,desplazamiento):
    print(f'{i} s: {f(i)} variable dependiente')

tabla_datos()

# %% [markdown]
# ## Aplicar calculadora en python  resultados con n decimales

# %%
R = (12.345*2.5)
print(f'{R:.2F}')      #solo valor
print(f'variable independiente xx (unidad medida), se han  {(h):.0f} variable dependiente (unidad de medida)')
# Out:
# 30.86

# %% [markdown]
# ## Llamar a una función

# %%
resultado = suma(3, 4) # el valor de resultado será 7

# %% [markdown]
# ## Graficar una función

# %%
def f(x):
    return # función a graficar

x = np.arange(valor inicial, valor final, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Ejemplo completo :

# %%
# Función que calcula el consumo de energía según el tiempo
def E(t):
    return 50 * np.log10(t + 1) + 200

# Genera valores de tiempo desde 0 hasta 1200 horas
n = np.arange(0, 1200, 0.1)

# Grafica el tiempo (X) y el consumo de energía (Y)
plt.plot(n, E(n), label='E(t)')

# Marca el resultado a las 30 horas con un punto rojo
plt.plot(30, E(30), 'ro',label=f"30 horas = {E(30):.0f} kWh")

# Título y nombres de los ejes
plt.title("Consumo de energía del data center")
plt.ylabel("Y = Consumo de energía (kWh)")
plt.xlabel("X = Tiempo (horas)")

# Muestra la leyenda y la cuadrícula
plt.legend()
plt.grid()

# Muestra el gráfico
plt.show()

# %% [markdown]
# ## GRAFICAR DOS FUNCIONES

# %%
def f(x):
    return # primera función a graficar

def g(x):
    return # segunda función a graficar


x = np.arange(valor_inicial, valor_final, paso)

plt.plot(x, f(x), label='f(x)')   # Grafica la primera función
plt.plot(x, g(x), label='g(x)')   # Grafica la segunda función

plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')

plt.legend()   # Muestra cuál curva corresponde a f(x) y cuál a g(x)
plt.grid()
plt.show()

# %% [markdown]
# Aqui esta un ejemplo f(x)=2x+10 y g(x)=x2+5

# %%
def f(x):
    return 2 * x + 10

def g(x):
    return x**2 + 5

x = np.arange(0, 15, 0.1)

# Graficar ambas funciones
plt.plot(x, f(x), label='Producto A')
plt.plot(x, g(x), label='Producto B')

# Resultados en el mes 10
plt.plot(10, f(10), 'ro', label=f'Resultado A = {f(10):.0f} ventas')
plt.plot(10, g(10), 'bo', label=f'Resultado B = {g(10):.0f} ventas')

# Títulos
plt.title('Comparación de ventas de dos productos')
plt.ylabel('Y = Cantidad de ventas')
plt.xlabel('X = Tiempo (meses)')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Función exponencial    Euler= e

# %%
#para escribir EULER = e = np.exp(t)
def f(x):
    retur np.exp(t)

# %% [markdown]
# Ejemplo de Euler normal $$W(t) = 100e^{-0.1t}$$

# %%
def W(t):
    return 100 * np.exp(-0.1 * t);
# aqui se espreso que la carga de trabajo al inicio es el 100% 
print(f"La carga de trabajo al inicio es el {W(0):.0f}%")
# Out:
# La carga de trabajo al inicio es el 100%

# %% [markdown]
# Tambien este pero con divicion $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$

# %%
def U(t):
    return 1000 / (1+9*np.exp(-0.5*t))

t = 12 # Aqui se espreso por 12 meses Por eso es 12
print(f'Trascurrido 12 meses la red social tiene {U(12):.0f} Usuario')
# Out:
# Trascurrido 12 meses la red social tiene 978 Usuario

# %% [markdown]
# Otro ejemplo $$T(t) = -0,5 t^{2} + 3 t + 20$$

# %%
def T(t):
    return -0.5 * t**2 + 3 * t + 20

print(f'La temperatura del servidor es {T(t):.0f}°C')
# Out:
# La temperatura del servidor es -16°C

# %% [markdown]
# # PARA MARCAR UN VALOR EN LOS GRAFICOS EJEMPLO  (4 ;U(4))

# %%
plt.plot(4,U(4),marker="o")

# %% [markdown]
# ## Encontrar raíces de una función SOLUCIONES fsolve

# %%
def f(x):
    return #'función igualada a cero'

#Valor/es inicial/es de la aproximación
xo = np.linspace(valor inicial, valor final, un valor ENTERO)

solucion = fsolve(f, xo)

print(f'A la XXX unidad medida VD {solucion[0]:.0f} unidad media VI.')  # LA IDEA ES RESPETAR UNIDA DE MEDIDAS

# %% [markdown]
# Ejemplo con este codigo:

# %%
def E(t):
    return 50 * np.log10(t + 1) + 200 - 350

solucion = fsolve(E, 1) # solucion = fsolve(E, t)

print(f'El consumo será de 350 kWh luego de {solucion[0]:.0f} horas')
# Out:
# El consumo será de 350 kWh luego de 999 horas

# %% [markdown]
# ## Encontrar forma algebraica de una función lineal

# %%
x = np.array([valor 1, valor 2, valor 3, …, valor n])
y = np.array([valor 1, valor 2, valor 3, …, valor n])
#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)
