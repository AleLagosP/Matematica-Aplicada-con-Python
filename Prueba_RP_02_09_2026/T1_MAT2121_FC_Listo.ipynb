# %% [markdown]
# Nombres: Alejandro Lagoos -  Alonso Vargas
# Sesion: MATEMATICA APLICADA_015V
# Fecha: 02/09/2026

# %% [markdown]
# ## LIBRERIA PYTHON

# %%
import numpy as np                  # Cálculos numéricos, vectores y matrices              
import matplotlib.pyplot as plt     # Creación de gráficos
from scipy.optimize import fsolve   # Resolución numérica de ecuaciones

# %% [markdown]
# # Lluvias torrenciales, un desafío para las ciudades — ¿podrás evitar el diluvio?

# %% [markdown]
# ## Instrucciones
#
# 1. Lea detenidamente el enunciado y las preguntas.
# 2. Escriba sus desarrollos a continuación de la celda que dice “Desarrollo”.
# 3. Sus respuestas deben estar justificadas y su desarrollo debe ser ordenado y claro.
# 4. Se sugiere usar una celda de texto (markdown) con el número de la pregunta, una o más celdas de código para el desarrollo y luego una celda de texto (markdown) para escribir la respuesta.
# 5. Guarde su progreso antes de cerrar el programa.
# 6. Se prohíbe el uso de IA.

# %% [markdown]
# ## Pregunta de la prueba

# %% [markdown]
# ## Enunciado

# %% [markdown]
# En época invernal, es común que algunas ciudades experimenten lluvias intensas, lo que puede poner a prueba su infraestructura. Este año, ciudades como Valparaíso, Santiago y Concepción han registrado precipitaciones que requieren atención especial.
#
#
# Durante un día de lluvia podemos representar la cantidad de agua acumulada, en milímetros (mm), en cada ciudad con respecto al tiempo transcurrido en horas (t) desde las 6 de la mañana, a través de las siguientes funciones cuadráticas:
#
# **Valparaíso**: $$V(t)=0,9t^{2}+12,5t+36$$
#
# **Santiago**: $$S(t) =0,95t^{2}+16,8t+31$$
#
# **Concepción**: $$C(t) = 1,1t^{2}+19,4t+26$$
#
# Se sabe que los sistemas de alcantarillado de las ciudades no pueden acumular más de 100 mm de agua. Si se supera este umbral, será necesario enviar equipos de emergencia para evitar inundaciones.
#
# Con ayuda de Python responde las siguientes preguntas:
#
# 1. ¿Cuál es el valor de $t$ a las 07:30 de la mañana? ¿Cuál sería la cantidad de agua acumulada en Concepción a las 07:30 de la mañana?
# 1. En un mismo grafico, trace las tres funciones considerando que se pronostican 14 horas de lluvia.
# 1. ¿Cuál será la primera ciudad en requerir la ayuda de los equipos de emergencia?
# 1. Entre las 3 y 5 de la tarde, ¿en qué ciudad cayó más agua?

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# 1. Variables dependiente e idependientes:
#
# DV: Cantidad de agua acumulada (milimetros)
#
# DI: Tiempos concurridos (Horas)

# %%
#Determinando las ciudades del primera hora de lluvia a las 6 de la mañana:

#1. valparaiso
def V(t):
    return 0.9*t**2 + 12.5*t +36

print(f'El valor de Tiempo de valparaiso es {V(0):.0f} Milimetros cada hora')

# 2. Santiago
def S(t):
    return 0.95*t**2 + 16.8*t +31
print(f'El valor de Tiempo de santiago es {S(0):.0f} Milimetros cada hora')

#3. Comcepcion 
def C(t):   
    return 1.1*t**2+ 19.4*t + 26
print(f'El valor de Tiempo de concepcion es {C(0):.0f} Milimetros cada hora')
# Out:
# El valor de Tiempo de valparaiso es 36 Milimetros cada hora
# El valor de Tiempo de santiago es 31 Milimetros cada hora
# El valor de Tiempo de concepcion es 26 Milimetros cada hora

# %%
#Pregunta 1:
def C(t):
    return 1.1*t**2+ 19.4*t + 26

t= 1.5

print(f"La cantidad de agua acumulada es {C(t):.0f} milimetros a las 7:30 de la mañana")
# Out:
# La cantidad de agua acumulada es 58 milimetros a las 7:30 de la mañana

# %%
#Pregunta 2, Grafico

def V(t):
    return 0.9*t**2 + 12.5*t +36

def S(t):
    return 0.95*t**2 + 16.8*t +31

def C(t):
    return 1.1*t**2+ 19.4*t + 26

t= np.arange(0, 15 ,1)

plt.plot(t, V(t), label='Valparaiso')
plt.plot(t, S(t), label='Santiago')
plt.plot(t, C(t), label='Concepcion')
plt.plot(14, V(14), 'ro', label=f'Resultado V= {V(14):.0f} (mm)')
plt.plot(14, S(14), 'bo', label=f'Resultado S = {S(14):.0f} (mm)')
plt.plot(14, C(14), 'go', label=f'Resultado C = {C(14):.0f} (mm)')
plt.title('Pronostico del Clima de cada ciudad')
plt.ylabel('Y = Cantidad de lluvia(Milimetros)')
plt.xlabel('X = Tiempo (Horas)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 3 ¿Cuál será la primera ciudad en requerir la ayuda de los equipos de emergencia?
#
# R: La ciudad que requiere primeros auxilio es concepcion que pasa el triple de de los 100 MM que su resultado es 330 milimetros

# %% [markdown]
# 4 Entre las 3 y 5 de la tarde, ¿en qué ciudad cayó más agua?

# %%
#4
def C(t):
    return 1.1*t**2+ 19.4*t + 26

print(f'La cantidad de agua acumulada es {C(9):.0f} milimetros a las 3 de la tarde')
print(f'La cantidad de agua acumulada es {C(11):.0f} milimetros a las 5 de la tarde')
# Out:
# La cantidad de agua acumulada es 290 milimetros a las 3 de la tarde
# La cantidad de agua acumulada es 372 milimetros a las 5 de la tarde

# %%
def C(t):
    return 1.1*t**2 + 19.4*t + 26

agua = C(11) - C(9)

print(f'La cantidad de agua caída entre las 3 y 5 de la tarde es {agua:.1f} milímetros')
# Out:
# La cantidad de agua caída entre las 3 y 5 de la tarde es 82.8 milímetros

# %% [markdown]
# R: Mirando el Grafico la ciudad en donde cayó más agua entre las horas 3 y 5 es de 82,8 mm de agua
